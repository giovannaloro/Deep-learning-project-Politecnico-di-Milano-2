# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# %cd /gdrive/My Drive/[2024-2025] AN2DL HW2
# Out:
# Mounted at /gdrive
# /gdrive/.shortcut-targets-by-id/1z5t8kqLSNnsGWmeDMitEc48VDF9xBUOx/[2024-2025] AN2DL HW2

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import os
import math
from PIL import Image
from keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.1

# %%
# Loading the cleaned dataset
data = np.load("mars_cleaned_dataset.npz")
X = data["X_train"]
y = data["y_train"]
X_final_test = data["X_test"]
print(X.shape)
print(y.shape)
print(X_final_test.shape)

#Splitting
test_size = 0.15
adjusted_val_size = 0.176
X_trainval, X_test, y_trainval, y_test = train_test_split( X, y, test_size=test_size, random_state=seed)
X_train, X_val, y_train, y_val = train_test_split( X_trainval, y_trainval, test_size=adjusted_val_size, random_state=seed)

#Turning np dataset in tf dataset
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test))
final_test_dataset = tf.data.Dataset.from_tensor_slices(X_final_test)
# Out:
# (2505, 64, 128)
# (2505, 64, 128)
# (10022, 64, 128)

# %%
def tile_dataset(dataset, image_shape, label_shape):
    """
    Tiles each image and segmentation label in the dataset into two halves along the width.

    Args:
    - dataset (tf.data.Dataset): A dataset of (image, label) pairs.
    - image_shape (tuple): The shape of each image (height, width, channels).
    - label_shape (tuple): The shape of each segmentation label (height, width, channels).

    Returns:
    - tf.data.Dataset: A new dataset with tiled images and labels.
    """
    def tile_image_label(image, label):
        # Split the image and label along the width (axis=1)
        image_tile1, image_tile2 = tf.split(image, num_or_size_splits=2, axis=1)
        label_tile1, label_tile2 = tf.split(label, num_or_size_splits=2, axis=1)

        # Combine the tiles into two new (image, label) pairs
        tiled1 = (image_tile1, label_tile1)
        tiled2 = (image_tile2, label_tile2)
        return tf.data.Dataset.from_tensors(tiled1).concatenate(tf.data.Dataset.from_tensors(tiled2))

    # Map the tile operation over the dataset
    tiled_dataset = dataset.flat_map(lambda image, label: tile_image_label(image, label))

    return tiled_dataset


train_dataset = tile_dataset(train_dataset, (64, 64, 1), (64, 64, 1))
val_dataset = tile_dataset(val_dataset, (64, 64, 1), (64, 64, 1))
test_dataset = tile_dataset(test_dataset, (64, 64, 1), (64, 64, 1))

# %%
# Define class labels for better readability
class_labels = ["Background", "Soil", "Bedrock", "Sand", "Big Rock"]

# Ensure input is a 1D array of integers
y_vector = np.ravel(y_train).astype(int)

# Calculate class counts
class_counts = np.bincount(y_vector, minlength=len(class_labels))

# Calculate frequency percentages
class_frequencies = class_counts / np.sum(class_counts) * 100

# Display class counts and percentages
print("Class Distribution:\n")
for i, (count, freq) in enumerate(zip(class_counts, class_frequencies)):
    print(f"Class {i} ({class_labels[i]}):")
    print(f"    Pixels: {count}")
    print(f"    Frequency: {freq:.2f}%")

# Calculate raw weights as the inverse of the frequencies
raw_weights = {cls: 1.0 / freq for cls, freq in zip(range(len(class_frequencies)), class_frequencies)}

# Normalize the weights so that their sum equals the number of classes
sum_of_raw_weights = sum(raw_weights.values())
num_classes = len(class_labels)

normalized_weights = {cls: (weight / sum_of_raw_weights) * num_classes for cls, weight in raw_weights.items()}

# Display results
print("Class Frequencies:", class_frequencies)
print("Raw Weights:", raw_weights)
print("Normalized Weights:", normalized_weights)
# Out:
# Class Distribution:
#
# Class 0 (Background):
#     Pixels: 3512496
#     Frequency: 24.45%
# Class 1 (Soil):
#     Pixels: 4863886
#     Frequency: 33.85%
# Class 2 (Bedrock):
#     Pixels: 3498998
#     Frequency: 24.35%
# Class 3 (Sand):
#     Pixels: 2473313
#     Frequency: 17.21%
# Class 4 (Big Rock):
#     Pixels: 20075
#     Frequency: 0.14%
# Class Frequencies: [24.44535259 33.85040388 24.35141273 17.21311806  0.13971274]
# Raw Weights: {0: 0.04090757114029454, 1: 0.029541745016227763, 2: 0.0410653792885849, 3: 0.05809522692841545, 4: 7.157543212951432}
# Normalized Weights: {0: 0.027915051306267202, 1: 0.02015908803229728, 2: 0.02802273852487435, 3: 0.0396437919717635, 4: 4.884259330164797}

# %%
#define loss function
def focal_loss(alpha=0.25, gamma=2.0):
    def loss_fn(y_true, y_pred):
        y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=y_pred.shape[-1])
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0)
        cross_entropy = -y_true * tf.math.log(y_pred)
        weights = alpha * tf.pow(1 - y_pred, gamma)
        focal_loss = tf.reduce_sum(weights * cross_entropy, axis=-1)
        return tf.reduce_mean(focal_loss)
    return loss_fn

def standard_loss():
  return tf.keras.losses.SparseCategoricalCrossentropy()

def weighted_cross_entropy_loss(weights):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.int32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0)  # Avoid log(0)
        y_true_one_hot = tf.one_hot(y_true, depth=len(weights))
        weights_tensor = tf.constant(list(weights.values()), dtype=tf.float32)  # Use list to extract values from dictionary
        weighted_cross_entropy = tf.reduce_sum(weights_tensor * y_true_one_hot * tf.math.log(y_pred), axis=-1)
        return -tf.reduce_mean(weighted_cross_entropy)
    return loss

def dice_loss(smooth = 1e-6):
  def loss(y_true, y_pred):
      y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=y_pred.shape[-1])
      y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0)  # Ensure numerical stability
      intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
      union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3])
      dice = (2. * intersection + smooth) / (union + smooth)
      return 1 - tf.reduce_mean(dice)
  return loss

def combined_loss(weights, alpha=0.5, beta=0.5):
    def loss(y_true, y_pred):
        wce_loss = weighted_cross_entropy_loss(weights)(y_true, y_pred)
        dice = dice_loss(y_true, y_pred)
        return alpha * dice + beta * wce_loss
    return loss

# %%
#augmentation, applied to train, validation and test
augment_geometrical = True
augment_noise = True
augment_texture = False

#balancing technique
balance = True #if true the rock class is oversampled based on rock_overaampling
rock_oversampling = 2 #values in [1,n]. 1 means no oversampling

#complexity parameters
STACK = 3 #the unet block stack
ADD_L = 0 #number of additional layers

#training parameters
BATCH_SIZE = 64
INPUT_SHAPE = (64, 64, 1)
NUM_CLASSES = 5
LEARNING_RATE = 1e-5
EPOCHS = 50
PATIENCE = 5

#loss will be the model's loss
loss = focal_loss()

# %%
def rock_oversample(dataset, oversampling_ratio=1):
    """
    Oversample elements in the dataset where the label contains the class 'Big Rock' (class label 4).

    Parameters:
    dataset: tf.data.Dataset - The input dataset containing (image, label) pairs
    oversampling_ratio: int - The number of times to duplicate elements with 'Big Rock'

    Returns:
    tf.data.Dataset - The oversampled dataset
    """
    def contains_big_rock(image, label):
        """
        Check if the label contains the undersampled class 'Big Rock' (class label 4).
        """
        return tf.reduce_any(label == 4)

    def oversample_fn(image, label):
        """
        Duplicate the (image, label) pair if it contains 'Big Rock'.
        """
        # If contains 'Big Rock', repeat the element 'oversampling_ratio' times
        return tf.cond(
            contains_big_rock(image, label),
            lambda: tf.data.Dataset.from_tensors((image, label)).repeat(oversampling_ratio),
            lambda: tf.data.Dataset.from_tensors((image, label))
        )

    # Apply the oversampling logic to each element using flat_map
    oversampled_dataset = dataset.flat_map(oversample_fn)

    # Shuffle the oversampled dataset to mix the duplicates with the original data
    oversampled_dataset = oversampled_dataset.shuffle(buffer_size=1000)

    return oversampled_dataset

if balance:
  # training oversample
  print("Oversampling dataset...")
  train_dataset = rock_oversample(
      dataset=train_dataset,
      oversampling_ratio=rock_oversampling
  )
# Out:
# Oversampling dataset...

# %% [markdown]
# Print shapes

# %%
for image, label in train_dataset.take(1):  # Take one batch to inspect the shape
    print(f"Image shape: {image.shape}")
    print(f"Label shape: {label.shape}")

# To get the number of elements in the dataset
num_images = sum(1 for _ in train_dataset)
print(f"Number of images in the train dataset: {num_images}")

for image, label in val_dataset.take(1):  # Take one batch to inspect the shape
    print(f"Image shape: {image.shape}")
    print(f"Label shape: {label.shape}")

# To get the number of elements in the dataset
num_images = sum(1 for _ in val_dataset)
print(f"Number of images in the val dataset: {num_images}")

for image, label in test_dataset.take(1):  # Take one batch to inspect the shape
    print(f"Image shape: {image.shape}")
    print(f"Label shape: {label.shape}")

# To get the number of elements in the dataset
num_images = sum(1 for _ in test_dataset)
print(f"Number of images in the test dataset: {num_images}")
# Out:
# Image shape: (64, 64)
# Label shape: (64, 64)
# Number of images in the train dataset: 3584
# Image shape: (64, 64)
# Label shape: (64, 64)
# Number of images in the val dataset: 750
# Image shape: (64, 64)
# Label shape: (64, 64)
# Number of images in the test dataset: 752

# %% [markdown]
# Define augmentations and perform augmentations on the dataset

# %%
import tensorflow as tf
#import tensorflow_addons as tfa
import numpy as np

# Define augmentation functions

@tf.function
def random_flip(image, label, seed=None):
    """Consistently applies random horizontal flip."""
    if seed is None:
        seed = np.random.randint(0, 1000000)


    # Ensure image and label have a channel dimension
    image = tf.expand_dims(image, axis=-1)
    label = tf.expand_dims(label, axis=-1)

    image = tf.image.flip_left_right(image)
    label = tf.image.flip_left_right(label)

    # Remove the channel dimension
    image = tf.squeeze(image, axis=-1)
    label = tf.squeeze(label, axis=-1)

    return image, label


@tf.function
def random_vertical_flip(image, label, seed=None):
    """Consistently applies random vertical flip."""
    if seed is None:
        seed = np.random.randint(0, 1000000)


    # Ensure image and label have a channel dimension
    image = tf.expand_dims(image, axis=-1)
    label = tf.expand_dims(label, axis=-1)

    image = tf.image.flip_up_down(image)
    label = tf.image.flip_up_down(label)

    # Remove the channel dimension
    image = tf.squeeze(image, axis=-1)
    label = tf.squeeze(label, axis=-1)

    return image, label


import tensorflow as tf

@tf.function
def random_rescale(image, label, min_scale=1, max_scale=1.4, seed=None):

    if seed is not None:
        tf.random.set_seed(seed)

    # Add a channel dimension
    image = tf.expand_dims(image, axis=-1)
    label = tf.expand_dims(label, axis=-1)

    # Get the original image size
    original_height, original_width = tf.shape(image)[0], tf.shape(image)[1]

    # Generate a random scaling factor
    scale = tf.random.uniform([], minval=min_scale, maxval=max_scale, seed=seed)

    # Compute the new dimensions
    new_height = tf.cast(scale * tf.cast(original_height, tf.float32), tf.int32)
    new_width = tf.cast(scale * tf.cast(original_width, tf.float32), tf.int32)

    # Resize the image and label
    image_resized = tf.image.resize(image, [new_height, new_width], method='bilinear')
    label_resized = tf.image.resize(label, [new_height, new_width], method='nearest')  # Nearest neighbor for labels

    # Crop back to the original size (center crop)
    image_rescaled = tf.image.resize_with_crop_or_pad(image_resized, original_height, original_width)
    label_rescaled = tf.image.resize_with_crop_or_pad(label_resized, original_height, original_width)
    #rebring to 2d image
    # Add a channel dimension
    image_rescaled = tf.squeeze(image_rescaled, axis=-1)
    label_rescaled = tf.squeeze(label_rescaled, axis=-1)

    return image_rescaled, label_rescaled

def random_rotation(image, label, max_angle=30, seed=None):
    if seed is None:
        seed = np.random.randint(0, 1000000)

    # Generate a random angle in degrees
    angle = tf.random.uniform([], minval=-max_angle, maxval=max_angle, seed=seed)
    angle_rad = angle * (3.14159265359 / 180)  # Convert degrees to radians

    # Add a channel dimension if the image is 2D
    if len(image.shape) == 2:
        image = tf.expand_dims(image, axis=-1)
        label = tf.expand_dims(label, axis=-1)

    # Rotate image and label
    image_rotated = tf.image.rot90(image, k=tf.cast(angle_rad // 90, tf.int32))
    label_rotated = tf.image.rot90(label, k=tf.cast(angle_rad // 90, tf.int32))

    # Remove the channel dimension if it was added
    if len(image.shape) == 3 and image.shape[-1] == 1:
        image_rotated = tf.squeeze(image_rotated, axis=-1)
        label_rotated = tf.squeeze(label_rotated, axis=-1)

    return image_rotated, label_rotated


@tf.function
def random_gaussian_noise(image, label, mean=0.0, stddev=1.0, seed=None):
    if seed is None:
        seed = np.random.randint(0, 1000000)

    # Ensure image is one-channel and in float32 for noise addition
    image = tf.cast(image, tf.float32)

    # Generate Gaussian noise with the same shape as the image
    noise = tf.random.normal(shape=tf.shape(image), mean=mean, stddev=stddev, seed=seed)

    # Add noise to the image
    noisy_image = image + noise

    # Clip values to maintain valid range [0, 255]
    noisy_image = tf.clip_by_value(noisy_image, 0.0, 255.0)

    # Cast the noisy image to float64 (64-bit)
    noisy_image = tf.cast(noisy_image, tf.float64)

    return noisy_image, label




@tf.function
def random_brightness(image, label, max_delta=30, seed=None):
    """Adjusts the brightness of the image by a random factor."""
    if seed is not None:
        tf.random.set_seed(seed)

    adjusted_image = tf.image.random_brightness(image, max_delta=max_delta)
    adjusted_image = tf.clip_by_value(adjusted_image, 0.0, 255.0)

    return adjusted_image, label


@tf.function
def random_contrast(image, label, lower=0.5, upper=1.5, seed=None):
    """Adjusts the contrast of the image by a random factor."""
    if seed is not None:
        tf.random.set_seed(seed)

    # Add a channel dimension
    image = tf.expand_dims(image, axis=-1)
    contrast_factor = tf.random.uniform([], lower, upper)
    adjusted_image = tf.image.adjust_contrast(image, contrast_factor)
    adjusted_image = tf.clip_by_value(adjusted_image, 0.0, 255.0)
    # Remove the channel dimension
    adjusted_image = tf.squeeze(adjusted_image, axis=-1)

    return adjusted_image, label

def augment_and_concat(image, label, augment_geometrical=False, augment_noise=False, augment_texture=False, seed=None):
    """Apply augmentation and concatenate augmented version with original."""
    augmented_images = [image]
    augmented_labels = [label]

    if augment_geometrical:
        image_flip, label_flip = random_flip(image, label, seed=seed)
        image_vertical_flip, label_vertical_flip = random_vertical_flip(image, label, seed=seed)
        image_rotation, label_rotation = random_rotation(image, label, seed=seed)
        augmented_images.extend([ image_flip, image_vertical_flip, image_rotation])
        augmented_labels.extend([ label_flip, label_vertical_flip, label_rotation])

    if augment_noise:
        image_noise, _ = random_gaussian_noise(image, label, seed=seed)
        augmented_images.append(image_noise)
        augmented_labels.append(label)

    if augment_texture:
        image_brightness, _ = random_brightness(image, label, seed=seed)
        image_contrast, _ = random_contrast(image, label, seed=seed)

        augmented_images.extend([image_brightness, image_contrast])
        augmented_labels.extend([label, label])

    return augmented_images, augmented_labels

def make_dataset(dataset, augment_geometrical=False, augment_noise=False, augment_texture=False, batch_size=64,batching=True  ,seed=None):
    """
    Applies augment_and_concat to each (image, segmentation_label) pair in a dataset
    and returns a new dataset containing all augmented versions.

    Args:
    - dataset: tf.data.Dataset, a dataset of (image, segmentation_label) pairs.
    - augment_geometrical: Whether to apply geometrical augmentations (flip, rotate, etc.).
    - augment_noise: Whether to apply noise augmentations (Gaussian noise).
    - augment_texture: Whether to apply texture augmentations (brightness, contrast).
    - seed: Seed for reproducibility.

    Returns:
    - tf.data.Dataset: A new dataset containing all original and augmented versions.
    """
    def process_image_label(image, label):
        # Apply augmentations and get the augmented images and labels
        augmented_images, augmented_labels = augment_and_concat(
            image, label,
            augment_geometrical=augment_geometrical,
            augment_noise=augment_noise,
            augment_texture=augment_texture,
            seed=seed
        )

        # Stack augmented images and labels into a dataset
        augmented_dataset = tf.data.Dataset.from_tensor_slices((augmented_images, augmented_labels))
        return augmented_dataset

    def augment_and_flat_map(image, label):
        # Process each (image, label) and return the resulting dataset
        return process_image_label(image, label)

    # Apply augment_and_flat_map to each (image, label) in the dataset and flatten the result
    augmented_dataset = dataset.flat_map(augment_and_flat_map)
    augmented_dataset = augmented_dataset.shuffle(buffer_size=50000).batch(batch_size)
    return augmented_dataset

# Create the datasets
print("Creating datasets...")

train_dataset = make_dataset(
      dataset=train_dataset,
      augment_geometrical=augment_geometrical,
      augment_noise=augment_noise,
      augment_texture=augment_texture,
      batch_size=BATCH_SIZE,
      seed=seed
  )

val_dataset = make_dataset(
    dataset=val_dataset,
    augment_geometrical=augment_geometrical,
    augment_noise=augment_noise,
    augment_texture=augment_texture,
    batch_size=BATCH_SIZE,
    seed=seed
)
test_dataset = make_dataset(
    dataset=test_dataset,
    augment_geometrical=augment_geometrical,
    augment_noise=augment_noise,
    augment_texture=augment_texture,
    batch_size=BATCH_SIZE,
    seed=seed
)

print("Datasets created!")
# Out:
# Creating datasets...
# Datasets created!

# %% [markdown]
# Normalize dataset

# %%
#Dataset normalization
def normalize_dataset(dataset):
    return dataset.map(lambda image, label: (tf.cast(image, tf.float32) / 255.0, label))

def normalize_dataset_no_label(dataset):
    return dataset.map(lambda image: tf.cast(image, tf.float32) / 255.0)

train_dataset = normalize_dataset(train_dataset)
val_dataset = normalize_dataset(val_dataset)
test_dataset = normalize_dataset(test_dataset)
final_test_dataset = normalize_dataset_no_label(final_test_dataset)

# %%
# Extract images (X_train) and labels (y_train) from the dataset
def to_np(dataset):
  # Initialize an empty list to store images
  X_np = []
  for x in dataset.as_numpy_iterator():
      X_np.append(x)
  # Convert lists to NumPy arrays
  X_np = np.array(X_np)
  print("X_train_np shape:", X_np.shape)
  return X_np

X_final_test = to_np(final_test_dataset)
# Out:
# X_train_np shape: (10022, 64, 128)

# %% [markdown]
# Check dataset shapes

# %%
# Define custom Mean Intersection Over Union metric
@tf.keras.utils.register_keras_serializable()
class MeanIntersectionOverUnion(tf.keras.metrics.MeanIoU):
    def __init__(self, num_classes, labels_to_exclude=None, name="mean_iou", dtype=None):
        super(MeanIntersectionOverUnion, self).__init__(num_classes=num_classes, name=name, dtype=dtype)
        if labels_to_exclude is None:
            labels_to_exclude = [0]  # Default to excluding label 0
        self.labels_to_exclude = labels_to_exclude

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Convert predictions to class labels
        y_pred = tf.math.argmax(y_pred, axis=-1)

        # Flatten the tensors
        y_true = tf.reshape(y_true, [-1])
        y_pred = tf.reshape(y_pred, [-1])

        # Apply mask to exclude specified labels
        for label in self.labels_to_exclude:
            mask = tf.not_equal(y_true, label)
            y_true = tf.boolean_mask(y_true, mask)
            y_pred = tf.boolean_mask(y_pred, mask)

        # Update the state
        return super().update_state(y_true, y_pred, sample_weight)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Callbacks
lr_reduction = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    patience=PATIENCE,
    min_lr=1e-6,
    factor=0.2,
    verbose=1
)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=EPOCHS,
    restore_best_weights=True
)
callbacks = [lr_reduction, early_stopping]

# %% [markdown]
# # Blocks

# %%
import json
import datetime
from tensorflow.keras.callbacks import ModelCheckpoint

# Define U-Net block
def unet_block(input_tensor, filters, kernel_size=3, activation='leaky_relu', stack=STACK, name=''):
    # Initialise the input tensor
    x = input_tensor

    # Apply a sequence of Conv2D, Batch Normalisation, and Activation layers for the specified number of stacks
    for i in range(stack):
        x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + 'conv' + str(i + 1))(x)
        x = tfkl.BatchNormalization(name=name + 'bn' + str(i + 1))(x)
        x = tfkl.Activation(activation, name=name + 'activation' + str(i + 1))(x)
    # Return the transformed tensor
    return x

#Define bottlenech U-net block
def unet_block_bottleneck(input_tensor, filters, kernel_size=3, activation='leaky_relu', stack=STACK, name=''):
    # Initialise the input tensor
    x = input_tensor

    # Apply a sequence of Conv2D, Batch Normalisation, and Activation layers for the specified number of stacks
    for i in range(stack):
        x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + 'conv' + str(i + 1))(x)
        x = tfkl.BatchNormalization(name=name + 'bn' + str(i + 1))(x)
        x = tfkl.Activation(activation, name=name + 'activation' + str(i + 1))(x)
        # Squeeze-and-Excitation (SE) module
        channels = x.shape[-1]

        # Squeeze step
        se = tfkl.GlobalAveragePooling2D(name=f'{name}_squeeze_{i}')(x)

        # Excitation step
        se = tfkl.Dense(channels // 16, activation=activation, name=f'{name}_dense1_{i}')(se)
        se = tfkl.Dense(channels, activation='sigmoid', name=f'{name}_dense2_{i}')(se)

        # Scaling of the output with SE activation
        se = tfkl.Reshape((1, 1, channels))(se)
        x = tfkl.Multiply(name=f'{name}_scale_{i}')([x, se])
    # Return the transformed tensor
    return x

def residual_block(input_tensor, filters, kernel_size=3, name=''):
    x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + '_conv1')(input_tensor)
    x = tfkl.BatchNormalization(name=name + '_bn1')(x)
    x = tfkl.Activation('relu', name=name + '_relu1')(x)

    x = tfkl.Conv2D(filters, kernel_size=kernel_size, padding='same', name=name + '_conv2')(x)
    x = tfkl.BatchNormalization(name=name + '_bn2')(x)

    shortcut = tfkl.Conv2D(filters, 1, padding='same', name=name + '_shortcut')(input_tensor)
    x = tfkl.Add(name=name + '_add')([x, shortcut])
    return tfkl.Activation('relu', name=name + '_relu2')(x)

def attention_gate(skip, upsampled, filters, name):
    """
    Attention gate with additive attention.
    """
    gating = tfkl.Conv2D(filters, 1, padding='same', name=name + '_gate_conv')(upsampled)
    skip_transformed = tfkl.Conv2D(filters, 1, padding='same', name=name + '_skip_conv')(skip)
    combined = tfkl.Add(name=name + '_add')([gating, skip_transformed])
    attention = tfkl.Activation('sigmoid', name=name + '_sigmoid')(combined)
    return tfkl.Multiply(name=name + '_multiply')([skip, attention])

def gated_skip_connection(skip, upsampled, filters, name):
    """
    Gated skip connection with sigmoid activation.
    """
    gating = tfkl.Conv2D(filters, 1, padding='same', name=name + '_gate_conv')(upsampled)
    skip_transformed = tfkl.Conv2D(filters, 1, padding='same', name=name + '_skip_conv')(skip)
    combined = tfkl.Add(name=name + '_add')([gating, skip_transformed])
    gated = tfkl.Activation('sigmoid', name=name + '_sigmoid')(combined)
    return tfkl.Multiply(name=name + '_multiply')([skip, gated])

# %%
def train_unet(model, loss_fn, train_dataset, val_dataset, model_name='UNet'):
    global LEARNING_RATE, EPOCHS, NUM_CLASSES, callbacks

    metrics=["accuracy", MeanIntersectionOverUnion(num_classes=NUM_CLASSES, labels_to_exclude=[0])]

    # Compile the model
    model.compile(
        loss=[loss_fn, loss_fn, loss_fn],
        optimizer=tf.keras.optimizers.AdamW(LEARNING_RATE),
        metrics=[metrics, metrics, metrics]
    )

    # Train the model
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    ).history

    # Calculate the final validation MeanIoU
    final_val_meanIoU = round(max(history.get('val_mean_iou', [0])) * 100, 2)
    print(f'Final validation Mean Intersection Over Union: {final_val_meanIoU}%')

    # Create a timestamp for unique file naming
    timestamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

    # Save the model with the accuracy in the filename
    model_filename = f'{model_name}_{loss_fn.__class__.__name__}_{final_val_meanIoU}_{timestamp}.keras'
    model.save(model_filename)
    print(f'Model saved as {model_filename}')

    # Save training history as a JSON file
    history_filename = f"history_{model_name}_{loss_fn.__class__.__name__}_{timestamp}.json"
    with open(history_filename, 'w') as f:
        json.dump(history, f)
    print(f"Training history saved as {history_filename}")

    # Delete the model to free up resources
    del model

    # Return the history dictionary
    return history, model_filename

# %%
def plot_history(history, loss_fn):
    """
    Plots training and validation loss, accuracy, and mean IoU from the training history.

    Parameters:
    history (dict): The training history containing 'loss', 'val_loss', 'accuracy', 'val_accuracy',
                    'mean_iou', and 'val_mean_iou'.
    loss_fn (str): The loss function used in the training (e.g., 'SparseCategoricalCrossentropy').
    """
    metrics = {
        "Loss (" + loss_fn.__class__.__name__ + ")": ("loss", "val_loss"),
        "Accuracy": ("accuracy", "val_accuracy"),
        "Mean Intersection Over Union": ("mean_iou", "val_mean_iou")
    }

    # Plot the metrics
    for title, (train_key, val_key) in metrics.items():
        plt.figure(figsize=(18, 3))
        plt.plot(history[train_key], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
        plt.plot(history[val_key], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
        plt.title(title)
        plt.legend()
        plt.grid(alpha=0.3)
        plt.show()

# %%
from matplotlib.colors import ListedColormap

# Define class labels and colormap
CLASS_LABELS = {
    0: "Background",
    1: "Soil",
    2: "Bedrock",
    3: "Sand",
    4: "Big Rock"
}
COLORS = ["black", "brown", "gray", "yellow", "darkred"]
cmap = ListedColormap(COLORS)

def plot_triptychs(dataset, model, num_samples=1, seed=42):
    """
    Plot triptychs (original image, true mask, predicted mask) for samples from a tf.data.Dataset

    Parameters:
    dataset: tf.data.Dataset - The dataset containing image-label pairs
    model: tf.keras.Model - The trained model to generate predictions
    num_samples: int - Number of samples to plot
    seed: int - Random seed for shuffling the dataset
    """
    # Shuffle the dataset and then take `num_samples` random samples
    shuffled_dataset = dataset.shuffle(buffer_size=1000, seed=seed)
    samples = shuffled_dataset.take(num_samples)

    for images, labels in samples:
        # If we have a batch, take the first example
        if len(images.shape) == 4:  # Batch of images
            images = images[0:1]
            labels = labels[0:1]

        # Generate predictions
        pred = model.predict(images, verbose=0)
        pred = tf.math.argmax(pred, axis=-1)

        # Create figure with subplots
        fig, axes = plt.subplots(1, 3, figsize=(20, 4))

        # Plot original image
        axes[0].set_title("Original Image")
        axes[0].imshow(images[0], cmap='gray')  # Assuming grayscale images
        axes[0].axis('off')

        # Plot original mask
        axes[1].set_title("Original Mask")
        axes[1].imshow(labels[0], cmap=cmap, vmin=0, vmax=len(CLASS_LABELS)-1)
        axes[1].axis('off')

        # Plot predicted mask
        axes[2].set_title("Predicted Mask")
        im = axes[2].imshow(pred[0], cmap=cmap, vmin=0, vmax=len(CLASS_LABELS)-1)
        axes[2].axis('off')

        # Add a color legend for the segmentation classes
        cbar = plt.colorbar(im, ax=axes[2], fraction=0.022, pad=0.04)
        cbar.set_ticks(range(len(CLASS_LABELS)))
        cbar.set_ticklabels([CLASS_LABELS[i] for i in range(len(CLASS_LABELS))])

        plt.tight_layout()
        plt.show()
        plt.close()

# %% [markdown]
# ## Deep Supervision

# %% [markdown]
# Just three identical heads to see how model performance would chnage. Errors in the notebook, only due to the fact that the plot functions do not take three inputs as parameters but only one. Still meaningful.

# %%
def unet_trial3(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES, seed=seed):
    tf.random.set_seed(seed)
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    # Downsampling path
    down_block_1 = unet_block(input_layer, 32, name='down_block1_')
    d1 = tfkl.MaxPooling2D()(down_block_1)

    down_block_2 = unet_block(d1, 64, name='down_block2_')
    d2 = tfkl.MaxPooling2D()(down_block_2)

    # Bottleneck
    bottleneck = unet_block_bottleneck(d2, 128, name='bottleneck')

    # Upsampling path
    u1 = tfkl.UpSampling2D()(bottleneck)
    u1 = tfkl.Concatenate()([u1, down_block_2])
    u1 = unet_block(u1, 64, name='up_block1_')

    u2 = tfkl.UpSampling2D()(u1)
    u2 = tfkl.Concatenate()([u2, down_block_1])
    u2 = unet_block(u2, 32, name='up_block2_')

    # Deep supervision outputs
    output_main = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='output_main')(u2)
    output_aux1 = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='output_aux1')(u1)
    output_aux2 = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='output_aux2')(bottleneck)

    model = tf.keras.Model(inputs=input_layer, outputs=[output_main, output_aux1, output_aux2], name='UNet_Trial3')
    return model

# %%
training, model_filename = train_unet(
    model=unet_trial3(),
    loss_fn=loss,
    train_dataset=train_dataset,
    val_dataset=val_dataset,
    model_name='deep_supervision'
)
# Out:
# Epoch 1/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 76s 109ms/step - loss: 0.2703 - output_main_accuracy: 0.3437 - output_main_mean_iou: 0.1446 - val_loss: 0.4377 - val_output_main_accuracy: 0.2671 - val_output_main_mean_iou: 0.0889 - learning_rate: 1.0000e-05
# Epoch 2/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 57s 93ms/step - loss: 0.1688 - output_main_accuracy: 0.5569 - output_main_mean_iou: 0.2885 - val_loss: 0.1487 - val_output_main_accuracy: 0.6244 - val_output_main_mean_iou: 0.3555 - learning_rate: 1.0000e-05
# Epoch 3/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 90ms/step - loss: 0.1456 - output_main_accuracy: 0.6027 - output_main_mean_iou: 0.3263 - val_loss: 0.1294 - val_output_main_accuracy: 0.6530 - val_output_main_mean_iou: 0.3815 - learning_rate: 1.0000e-05
# Epoch 4/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - loss: 0.1348 - output_main_accuracy: 0.6227 - output_main_mean_iou: 0.3416 - val_loss: 0.1249 - val_output_main_accuracy: 0.6571 - val_output_main_mean_iou: 0.3794 - learning_rate: 1.0000e-05
# Epoch 5/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - loss: 0.1279 - output_main_accuracy: 0.6346 - output_main_mean_iou: 0.3513 - val_loss: 0.1152 - val_output_main_accuracy: 0.6738 - val_output_main_mean_iou: 0.3900 - learning_rate: 1.0000e-05
# Epoch 6/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 39s 91ms/step - loss: 0.1218 - output_main_accuracy: 0.6431 - output_main_mean_iou: 0.3570 - val_loss: 0.1112 - val_output_main_accuracy: 0.6788 - val_output_main_mean_iou: 0.3939 - learning_rate: 1.0000e-05
# Epoch 7/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 90ms/step - loss: 0.1181 - output_main_accuracy: 0.6498 - output_main_mean_iou: 0.3634 - val_loss: 0.1089 - val_output_main_accuracy: 0.6821 - val_output_main_mean_iou: 0.3980 - learning_rate: 1.0000e-05
# Epoch 8/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 91ms/step - loss: 0.1127 - output_main_accuracy: 0.6635 - output_main_mean_iou: 0.3728 - val_loss: 0.1046 - val_output_main_accuracy: 0.6940 - val_output_main_mean_iou: 0.4059 - learning_rate: 1.0000e-05
# Epoch 9/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 91ms/step - loss: 0.1101 - output_main_accuracy: 0.6667 - output_main_mean_iou: 0.3766 - val_loss: 0.1011 - val_output_main_accuracy: 0.6995 - val_output_main_mean_iou: 0.4117 - learning_rate: 1.0000e-05
# Epoch 10/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - loss: 0.1081 - output_main_accuracy: 0.6671 - output_main_mean_iou: 0.3760 - val_loss: 0.1033 - val_output_main_accuracy: 0.6955 - val_output_main_mean_iou: 0.4052 - learning_rate: 1.0000e-05
# Epoch 11/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 39s 91ms/step - loss: 0.1044 - output_main_accuracy: 0.6756 - output_main_mean_iou: 0.3826 - val_loss: 0.1001 - val_output_main_accuracy: 0.6943 - val_output_main_mean_iou: 0.4050 - learning_rate: 1.0000e-05
# Epoch 12/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 90ms/step - loss: 0.1035 - output_main_accuracy: 0.6740 - output_main_mean_iou: 0.3816 - val_loss: 0.0964 - val_output_main_accuracy: 0.7019 - val_output_main_mean_iou: 0.4106 - learning_rate: 1.0000e-05
# Epoch 13/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 90ms/step - loss: 0.1026 - output_main_accuracy: 0.6767 - output_main_mean_iou: 0.3835 - val_loss: 0.0958 - val_output_main_accuracy: 0.7000 - val_output_main_mean_iou: 0.4117 - learning_rate: 1.0000e-05
# Epoch 14/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - loss: 0.0995 - output_main_accuracy: 0.6825 - output_main_mean_iou: 0.3906 - val_loss: 0.0926 - val_output_main_accuracy: 0.7119 - val_output_main_mean_iou: 0.4234 - learning_rate: 1.0000e-05
# Epoch 15/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 39s 90ms/step - loss: 0.0970 - output_main_accuracy: 0.6863 - output_main_mean_iou: 0.3964 - val_loss: 0.0919 - val_output_main_accuracy: 0.7114 - val_output_main_mean_iou: 0.4187 - learning_rate: 1.0000e-05
# Epoch 16/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 90ms/step - loss: 0.0978 - output_main_accuracy: 0.6832 - output_main_mean_iou: 0.3916 - val_loss: 0.0898 - val_output_main_accuracy: 0.7123 - val_output_main_mean_iou: 0.4208 - learning_rate: 1.0000e-05
# Epoch 17/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 90ms/step - loss: 0.0945 - output_main_accuracy: 0.6934 - output_main_mean_iou: 0.3978 - val_loss: 0.0929 - val_output_main_accuracy: 0.7078 - val_output_main_mean_iou: 0.4153 - learning_rate: 1.0000e-05
# Epoch 18/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 91ms/step - loss: 0.0956 - output_main_accuracy: 0.6895 - output_main_mean_iou: 0.3960 - val_loss: 0.0930 - val_output_main_accuracy: 0.7088 - val_output_main_mean_iou: 0.4182 - learning_rate: 1.0000e-05
# Epoch 19/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - loss: 0.0922 - output_main_accuracy: 0.6973 - output_main_mean_iou: 0.4043 - val_loss: 0.0887 - val_output_main_accuracy: 0.7157 - val_output_main_mean_iou: 0.4251 - learning_rate: 1.0000e-05
# Epoch 20/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - loss: 0.0909 - output_main_accuracy: 0.6991 - output_main_mean_iou: 0.4031 - val_loss: 0.0903 - val_output_main_accuracy: 0.7095 - val_output_main_mean_iou: 0.4154 - learning_rate: 1.0000e-05
# Epoch 21/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 91ms/step - loss: 0.0899 - output_main_accuracy: 0.7020 - output_main_mean_iou: 0.4067 - val_loss: 0.0876 - val_output_main_accuracy: 0.7135 - val_output_main_mean_iou: 0.4219 - learning_rate: 1.0000e-05
# Epoch 22/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 39s 91ms/step - loss: 0.0898 - output_main_accuracy: 0.7035 - output_main_mean_iou: 0.4073 - val_loss: 0.0850 - val_output_main_accuracy: 0.7222 - val_output_main_mean_iou: 0.4285 - learning_rate: 1.0000e-05
# Epoch 23/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 90ms/step - loss: 0.0886 - output_main_accuracy: 0.7047 - output_main_mean_iou: 0.4085 - val_loss: 0.0867 - val_output_main_accuracy: 0.7198 - val_output_main_mean_iou: 0.4267 - learning_rate: 1.0000e-05
# Epoch 24/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 90ms/step - loss: 0.0868 - output_main_accuracy: 0.7088 - output_main_mean_iou: 0.4120 - val_loss: 0.0855 - val_output_main_accuracy: 0.7217 - val_output_main_mean_iou: 0.4300 - learning_rate: 1.0000e-05
# Epoch 25/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 90ms/step - loss: 0.0864 - output_main_accuracy: 0.7119 - output_main_mean_iou: 0.4153 - val_loss: 0.0858 - val_output_main_accuracy: 0.7240 - val_output_main_mean_iou: 0.4336 - learning_rate: 1.0000e-05
# Epoch 26/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 91ms/step - loss: 0.0852 - output_main_accuracy: 0.7114 - output_main_mean_iou: 0.4146 - val_loss: 0.0810 - val_output_main_accuracy: 0.7321 - val_output_main_mean_iou: 0.4409 - learning_rate: 1.0000e-05
# Epoch 27/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 90ms/step - loss: 0.0853 - output_main_accuracy: 0.7105 - output_main_mean_iou: 0.4163 - val_loss: 0.0836 - val_output_main_accuracy: 0.7238 - val_output_main_mean_iou: 0.4291 - learning_rate: 1.0000e-05
# Epoch 28/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - loss: 0.0844 - output_main_accuracy: 0.7133 - output_main_mean_iou: 0.4165 - val_loss: 0.0833 - val_output_main_accuracy: 0.7290 - val_output_main_mean_iou: 0.4392 - learning_rate: 1.0000e-05
# Epoch 29/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 90ms/step - loss: 0.0833 - output_main_accuracy: 0.7166 - output_main_mean_iou: 0.4199 - val_loss: 0.0841 - val_output_main_accuracy: 0.7240 - val_output_main_mean_iou: 0.4338 - learning_rate: 1.0000e-05
# Epoch 30/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - loss: 0.0819 - output_main_accuracy: 0.7199 - output_main_mean_iou: 0.4247 - val_loss: 0.0825 - val_output_main_accuracy: 0.7268 - val_output_main_mean_iou: 0.4340 - learning_rate: 1.0000e-05
# Epoch 31/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0810 - output_main_accuracy: 0.7222 - output_main_mean_iou: 0.4239
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 90ms/step - loss: 0.0810 - output_main_accuracy: 0.7222 - output_main_mean_iou: 0.4238 - val_loss: 0.0902 - val_output_main_accuracy: 0.7108 - val_output_main_mean_iou: 0.4170 - learning_rate: 1.0000e-05
# Epoch 32/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 91ms/step - loss: 0.0802 - output_main_accuracy: 0.7240 - output_main_mean_iou: 0.4290 - val_loss: 0.0803 - val_output_main_accuracy: 0.7343 - val_output_main_mean_iou: 0.4429 - learning_rate: 2.0000e-06
# Epoch 33/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - loss: 0.0798 - output_main_accuracy: 0.7254 - output_main_mean_iou: 0.4273 - val_loss: 0.0812 - val_output_main_accuracy: 0.7326 - val_output_main_mean_iou: 0.4429 - learning_rate: 2.0000e-06
# Epoch 34/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 44s 98ms/step - loss: 0.0798 - output_main_accuracy: 0.7260 - output_main_mean_iou: 0.4289 - val_loss: 0.0798 - val_output_main_accuracy: 0.7359 - val_output_main_mean_iou: 0.4451 - learning_rate: 2.0000e-06
# Epoch 35/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 91ms/step - loss: 0.0791 - output_main_accuracy: 0.7265 - output_main_mean_iou: 0.4313 - val_loss: 0.0797 - val_output_main_accuracy: 0.7356 - val_output_main_mean_iou: 0.4447 - learning_rate: 2.0000e-06
# Epoch 36/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 39s 91ms/step - loss: 0.0799 - output_main_accuracy: 0.7242 - output_main_mean_iou: 0.4287 - val_loss: 0.0797 - val_output_main_accuracy: 0.7356 - val_output_main_mean_iou: 0.4430 - learning_rate: 2.0000e-06
# Epoch 37/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 91ms/step - loss: 0.0789 - output_main_accuracy: 0.7263 - output_main_mean_iou: 0.4298 - val_loss: 0.0797 - val_output_main_accuracy: 0.7352 - val_output_main_mean_iou: 0.4435 - learning_rate: 2.0000e-06
# Epoch 38/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - loss: 0.0784 - output_main_accuracy: 0.7290 - output_main_mean_iou: 0.4301 - val_loss: 0.0802 - val_output_main_accuracy: 0.7346 - val_output_main_mean_iou: 0.4419 - learning_rate: 2.0000e-06
# Epoch 39/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - loss: 0.0780 - output_main_accuracy: 0.7307 - output_main_mean_iou: 0.4348 - val_loss: 0.0791 - val_output_main_accuracy: 0.7373 - val_output_main_mean_iou: 0.4462 - learning_rate: 2.0000e-06
# Epoch 40/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - loss: 0.0794 - output_main_accuracy: 0.7248 - output_main_mean_iou: 0.4280 - val_loss: 0.0791 - val_output_main_accuracy: 0.7369 - val_output_main_mean_iou: 0.4463 - learning_rate: 2.0000e-06
# Epoch 41/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 39s 90ms/step - loss: 0.0787 - output_main_accuracy: 0.7296 - output_main_mean_iou: 0.4315 - val_loss: 0.0787 - val_output_main_accuracy: 0.7376 - val_output_main_mean_iou: 0.4471 - learning_rate: 2.0000e-06
# Epoch 42/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 91ms/step - loss: 0.0781 - output_main_accuracy: 0.7302 - output_main_mean_iou: 0.4340 - val_loss: 0.0791 - val_output_main_accuracy: 0.7376 - val_output_main_mean_iou: 0.4471 - learning_rate: 2.0000e-06
# Epoch 43/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 92ms/step - loss: 0.0779 - output_main_accuracy: 0.7315 - output_main_mean_iou: 0.4334 - val_loss: 0.0795 - val_output_main_accuracy: 0.7377 - val_output_main_mean_iou: 0.4459 - learning_rate: 2.0000e-06
# Epoch 44/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - loss: 0.0772 - output_main_accuracy: 0.7299 - output_main_mean_iou: 0.4341 - val_loss: 0.0793 - val_output_main_accuracy: 0.7355 - val_output_main_mean_iou: 0.4444 - learning_rate: 2.0000e-06
# Epoch 45/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 91ms/step - loss: 0.0779 - output_main_accuracy: 0.7303 - output_main_mean_iou: 0.4325 - val_loss: 0.0795 - val_output_main_accuracy: 0.7348 - val_output_main_mean_iou: 0.4415 - learning_rate: 2.0000e-06
# Epoch 46/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0790 - output_main_accuracy: 0.7281 - output_main_mean_iou: 0.4317
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1e-06.
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 91ms/step - loss: 0.0790 - output_main_accuracy: 0.7281 - output_main_mean_iou: 0.4316 - val_loss: 0.0807 - val_output_main_accuracy: 0.7320 - val_output_main_mean_iou: 0.4395 - learning_rate: 2.0000e-06
# Epoch 47/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - loss: 0.0774 - output_main_accuracy: 0.7316 - output_main_mean_iou: 0.4348 - val_loss: 0.0783 - val_output_main_accuracy: 0.7393 - val_output_main_mean_iou: 0.4482 - learning_rate: 1.0000e-06
# Epoch 48/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 92ms/step - loss: 0.0767 - output_main_accuracy: 0.7333 - output_main_mean_iou: 0.4354 - val_loss: 0.0791 - val_output_main_accuracy: 0.7374 - val_output_main_mean_iou: 0.4460 - learning_rate: 1.0000e-06
# Epoch 49/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 39s 91ms/step - loss: 0.0770 - output_main_accuracy: 0.7345 - output_main_mean_iou: 0.4367 - val_loss: 0.0795 - val_output_main_accuracy: 0.7366 - val_output_main_mean_iou: 0.4455 - learning_rate: 1.0000e-06
# Epoch 50/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 39s 92ms/step - loss: 0.0773 - output_main_accuracy: 0.7293 - output_main_mean_iou: 0.4336 - val_loss: 0.0785 - val_output_main_accuracy: 0.7385 - val_output_main_mean_iou: 0.4468 - learning_rate: 1.0000e-06
# Final validation Mean Intersection Over Union: 0%
# Model saved as deep_supervision_function_0_20241205-174033.keras
# Training history saved as history_deep_supervision_function_20241205-174033.json

# %%
plot_history(training, loss)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-ed177d06cfba> in <cell line: 1>()
# ----> 1 plot_history(training, loss)
#
# <ipython-input-18-22a1bbe0c223> in plot_history(history, loss_fn)
#      17     for title, (train_key, val_key) in metrics.items():
#      18         plt.figure(figsize=(18, 3))
# ---> 19         plt.plot(history[train_key], label='Training', alpha=0.8, color='#ff7f0e', linewidth=2)
#      20         plt.plot(history[val_key], label='Validation', alpha=0.9, color='#5a9aa5', linewidth=2)
#      21         plt.title(title)
#
# KeyError: 'accuracy'

# %%
# Load model
model = tfk.models.load_model(model_filename, compile=False)
metrics=["accuracy", MeanIntersectionOverUnion(num_classes=NUM_CLASSES, labels_to_exclude=[0])]

# Compile the model with specified loss, optimizer, and metrics
model.compile(
    loss=[loss, loss, loss],
    optimizer=tfk.optimizers.AdamW(LEARNING_RATE),
    metrics=[metrics, metrics, metrics]
)

# Evaluate the model on the test set and print the results
test_loss, test_accuracy, test_mean_iou = model.evaluate(test_dataset, verbose=0, batch_size=10)
print(f'Test Accuracy: {round(test_accuracy, 4)}')
print(f'Test Mean Intersection over Union: {round(test_mean_iou, 4)}')

# Plot three random samples
plot_triptychs(train_dataset, model, num_samples=30)
# Out:
# Test Accuracy: 0.7229
# Test Mean Intersection over Union: 0.428
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-aa1cefdeab4b> in <cell line: 18>()
#      16
#      17 # Plot three random samples
# ---> 18 plot_triptychs(train_dataset, model, num_samples=30)
#
# <ipython-input-19-0288df6d276b> in plot_triptychs(dataset, model, num_samples, seed)
#      34         # Generate predictions
#      35         pred = model.predict(images, verbose=0)
# ---> 36         pred = tf.math.argmax(pred, axis=-1)
#      37
#      38         # Create figure with subplots
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     106       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107   ctx.ensure_initialized()
# --> 108   return ops.EagerTensor(value, ctx.device_name, dtype)
#     109
#     110
#
# ValueError: Can't convert non-rectangular Python sequence to Tensor.

# %%
#compute predictions
preds = model.predict(X_final_test)
preds = preds[0]
preds = np.argmax(preds, axis=-1)
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step

# %%
#to pandas dataframe
def y_to_df(y) -> pd.DataFrame:
    """Converts segmentation predictions into a DataFrame format for Kaggle."""
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
# Create and download the csv submission file
timestep_str = model_filename.replace("model_", "").replace(".keras", "")
submission_filename = f"submission_{timestep_str}.csv"
submission_df = y_to_df(preds)
submission_df.to_csv(submission_filename, index=False)

from google.colab import files
files.download(submission_filename)

# %% [markdown]
# ## Residual Connections

# %%
def unet_trial4(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES, seed=seed):
    tf.random.set_seed(seed)
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    # Downsampling path
    down_block_1 = residual_block(input_layer, 32, name='down_block1_')
    d1 = tfkl.MaxPooling2D()(down_block_1)

    down_block_2 = residual_block(d1, 64, name='down_block2_')
    d2 = tfkl.MaxPooling2D()(down_block_2)

    # Bottleneck
    bottleneck = residual_block(d2, 128, name='bottleneck')

    # Upsampling path
    u1 = tfkl.UpSampling2D()(bottleneck)
    u1 = tfkl.Concatenate()([u1, down_block_2])
    u1 = residual_block(u1, 64, name='up_block1_')

    u2 = tfkl.UpSampling2D()(u1)
    u2 = tfkl.Concatenate()([u2, down_block_1])
    u2 = residual_block(u2, 32, name='up_block2_')

    # Output Layer
    output_layer = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='output_layer')(u2)

    model = tf.keras.Model(inputs=input_layer, outputs=output_layer, name='UNet_Trial4')
    return model

# %%
training, model_filename = train_unet(
    model=unet_trial4(),
    loss_fn=loss,
    train_dataset=train_dataset,
    val_dataset=val_dataset,
    model_name='residual_connections'
)
# Out:
# Epoch 1/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 65s 92ms/step - accuracy: 0.2970 - loss: 0.3450 - mean_iou: 0.1450 - val_accuracy: 0.2245 - val_loss: 0.3079 - val_mean_iou: 0.0649 - learning_rate: 1.0000e-05
# Epoch 2/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 31s 72ms/step - accuracy: 0.4715 - loss: 0.1779 - mean_iou: 0.2426 - val_accuracy: 0.5379 - val_loss: 0.1537 - val_mean_iou: 0.2880 - learning_rate: 1.0000e-05
# Epoch 3/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.5234 - loss: 0.1527 - mean_iou: 0.2704 - val_accuracy: 0.5720 - val_loss: 0.1400 - val_mean_iou: 0.3054 - learning_rate: 1.0000e-05
# Epoch 4/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 75ms/step - accuracy: 0.5492 - loss: 0.1413 - mean_iou: 0.2853 - val_accuracy: 0.5953 - val_loss: 0.1300 - val_mean_iou: 0.3230 - learning_rate: 1.0000e-05
# Epoch 5/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 73ms/step - accuracy: 0.5649 - loss: 0.1352 - mean_iou: 0.2958 - val_accuracy: 0.6070 - val_loss: 0.1243 - val_mean_iou: 0.3298 - learning_rate: 1.0000e-05
# Epoch 6/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.5737 - loss: 0.1299 - mean_iou: 0.3009 - val_accuracy: 0.6163 - val_loss: 0.1195 - val_mean_iou: 0.3380 - learning_rate: 1.0000e-05
# Epoch 7/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 75ms/step - accuracy: 0.5824 - loss: 0.1269 - mean_iou: 0.3083 - val_accuracy: 0.6219 - val_loss: 0.1181 - val_mean_iou: 0.3438 - learning_rate: 1.0000e-05
# Epoch 8/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.5958 - loss: 0.1230 - mean_iou: 0.3158 - val_accuracy: 0.6284 - val_loss: 0.1145 - val_mean_iou: 0.3487 - learning_rate: 1.0000e-05
# Epoch 9/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 74ms/step - accuracy: 0.5985 - loss: 0.1209 - mean_iou: 0.3203 - val_accuracy: 0.6301 - val_loss: 0.1145 - val_mean_iou: 0.3513 - learning_rate: 1.0000e-05
# Epoch 10/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.5989 - loss: 0.1199 - mean_iou: 0.3198 - val_accuracy: 0.6347 - val_loss: 0.1130 - val_mean_iou: 0.3545 - learning_rate: 1.0000e-05
# Epoch 11/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.6057 - loss: 0.1172 - mean_iou: 0.3259 - val_accuracy: 0.6389 - val_loss: 0.1098 - val_mean_iou: 0.3585 - learning_rate: 1.0000e-05
# Epoch 12/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 75ms/step - accuracy: 0.6048 - loss: 0.1170 - mean_iou: 0.3247 - val_accuracy: 0.6468 - val_loss: 0.1074 - val_mean_iou: 0.3624 - learning_rate: 1.0000e-05
# Epoch 13/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 33s 74ms/step - accuracy: 0.6104 - loss: 0.1158 - mean_iou: 0.3293 - val_accuracy: 0.6435 - val_loss: 0.1084 - val_mean_iou: 0.3613 - learning_rate: 1.0000e-05
# Epoch 14/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 75ms/step - accuracy: 0.6157 - loss: 0.1143 - mean_iou: 0.3353 - val_accuracy: 0.6519 - val_loss: 0.1060 - val_mean_iou: 0.3707 - learning_rate: 1.0000e-05
# Epoch 15/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 75ms/step - accuracy: 0.6184 - loss: 0.1125 - mean_iou: 0.3388 - val_accuracy: 0.6475 - val_loss: 0.1063 - val_mean_iou: 0.3661 - learning_rate: 1.0000e-05
# Epoch 16/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 75ms/step - accuracy: 0.6166 - loss: 0.1131 - mean_iou: 0.3369 - val_accuracy: 0.6444 - val_loss: 0.1070 - val_mean_iou: 0.3585 - learning_rate: 1.0000e-05
# Epoch 17/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 74ms/step - accuracy: 0.6255 - loss: 0.1108 - mean_iou: 0.3409 - val_accuracy: 0.6510 - val_loss: 0.1051 - val_mean_iou: 0.3652 - learning_rate: 1.0000e-05
# Epoch 18/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 33s 74ms/step - accuracy: 0.6244 - loss: 0.1112 - mean_iou: 0.3422 - val_accuracy: 0.6567 - val_loss: 0.1029 - val_mean_iou: 0.3747 - learning_rate: 1.0000e-05
# Epoch 19/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - accuracy: 0.6276 - loss: 0.1098 - mean_iou: 0.3455 - val_accuracy: 0.6542 - val_loss: 0.1033 - val_mean_iou: 0.3696 - learning_rate: 1.0000e-05
# Epoch 20/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 75ms/step - accuracy: 0.6305 - loss: 0.1086 - mean_iou: 0.3465 - val_accuracy: 0.6644 - val_loss: 0.1008 - val_mean_iou: 0.3805 - learning_rate: 1.0000e-05
# Epoch 21/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 73ms/step - accuracy: 0.6319 - loss: 0.1083 - mean_iou: 0.3474 - val_accuracy: 0.6493 - val_loss: 0.1043 - val_mean_iou: 0.3637 - learning_rate: 1.0000e-05
# Epoch 22/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 75ms/step - accuracy: 0.6336 - loss: 0.1078 - mean_iou: 0.3489 - val_accuracy: 0.6512 - val_loss: 0.1042 - val_mean_iou: 0.3673 - learning_rate: 1.0000e-05
# Epoch 23/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 73ms/step - accuracy: 0.6347 - loss: 0.1079 - mean_iou: 0.3509 - val_accuracy: 0.6637 - val_loss: 0.1020 - val_mean_iou: 0.3799 - learning_rate: 1.0000e-05
# Epoch 24/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 73ms/step - accuracy: 0.6402 - loss: 0.1060 - mean_iou: 0.3559 - val_accuracy: 0.6576 - val_loss: 0.1018 - val_mean_iou: 0.3742 - learning_rate: 1.0000e-05
# Epoch 25/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 75ms/step - accuracy: 0.6409 - loss: 0.1064 - mean_iou: 0.3565 - val_accuracy: 0.6694 - val_loss: 0.0989 - val_mean_iou: 0.3843 - learning_rate: 1.0000e-05
# Epoch 26/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 33s 75ms/step - accuracy: 0.6407 - loss: 0.1057 - mean_iou: 0.3555 - val_accuracy: 0.6686 - val_loss: 0.0998 - val_mean_iou: 0.3845 - learning_rate: 1.0000e-05
# Epoch 27/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 75ms/step - accuracy: 0.6394 - loss: 0.1060 - mean_iou: 0.3558 - val_accuracy: 0.6653 - val_loss: 0.0995 - val_mean_iou: 0.3798 - learning_rate: 1.0000e-05
# Epoch 28/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 32s 74ms/step - accuracy: 0.6423 - loss: 0.1052 - mean_iou: 0.3568 - val_accuracy: 0.6697 - val_loss: 0.0996 - val_mean_iou: 0.3837 - learning_rate: 1.0000e-05
# Epoch 29/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 31s 73ms/step - accuracy: 0.6459 - loss: 0.1042 - mean_iou: 0.3604 - val_accuracy: 0.6755 - val_loss: 0.0978 - val_mean_iou: 0.3908 - learning_rate: 1.0000e-05
# Epoch 30/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - accuracy: 0.6495 - loss: 0.1031 - mean_iou: 0.3647 - val_accuracy: 0.6723 - val_loss: 0.0980 - val_mean_iou: 0.3847 - learning_rate: 1.0000e-05
# Epoch 31/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 75ms/step - accuracy: 0.6488 - loss: 0.1035 - mean_iou: 0.3619 - val_accuracy: 0.6692 - val_loss: 0.0989 - val_mean_iou: 0.3839 - learning_rate: 1.0000e-05
# Epoch 32/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 33s 75ms/step - accuracy: 0.6490 - loss: 0.1032 - mean_iou: 0.3633 - val_accuracy: 0.6747 - val_loss: 0.0969 - val_mean_iou: 0.3879 - learning_rate: 1.0000e-05
# Epoch 33/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.6511 - loss: 0.1025 - mean_iou: 0.3643 - val_accuracy: 0.6701 - val_loss: 0.0986 - val_mean_iou: 0.3840 - learning_rate: 1.0000e-05
# Epoch 34/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 32s 74ms/step - accuracy: 0.6488 - loss: 0.1024 - mean_iou: 0.3619 - val_accuracy: 0.6763 - val_loss: 0.0968 - val_mean_iou: 0.3896 - learning_rate: 1.0000e-05
# Epoch 35/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 75ms/step - accuracy: 0.6523 - loss: 0.1019 - mean_iou: 0.3658 - val_accuracy: 0.6768 - val_loss: 0.0968 - val_mean_iou: 0.3896 - learning_rate: 1.0000e-05
# Epoch 36/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.6535 - loss: 0.1016 - mean_iou: 0.3673 - val_accuracy: 0.6753 - val_loss: 0.0970 - val_mean_iou: 0.3859 - learning_rate: 1.0000e-05
# Epoch 37/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 75ms/step - accuracy: 0.6546 - loss: 0.1006 - mean_iou: 0.3681 - val_accuracy: 0.6848 - val_loss: 0.0947 - val_mean_iou: 0.3988 - learning_rate: 1.0000e-05
# Epoch 38/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 32s 74ms/step - accuracy: 0.6561 - loss: 0.1009 - mean_iou: 0.3675 - val_accuracy: 0.6787 - val_loss: 0.0952 - val_mean_iou: 0.3904 - learning_rate: 1.0000e-05
# Epoch 39/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 33s 75ms/step - accuracy: 0.6591 - loss: 0.0998 - mean_iou: 0.3713 - val_accuracy: 0.6841 - val_loss: 0.0946 - val_mean_iou: 0.3999 - learning_rate: 1.0000e-05
# Epoch 40/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 32s 74ms/step - accuracy: 0.6531 - loss: 0.1013 - mean_iou: 0.3656 - val_accuracy: 0.6847 - val_loss: 0.0938 - val_mean_iou: 0.4005 - learning_rate: 1.0000e-05
# Epoch 41/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 32s 73ms/step - accuracy: 0.6592 - loss: 0.1002 - mean_iou: 0.3707 - val_accuracy: 0.6845 - val_loss: 0.0942 - val_mean_iou: 0.3986 - learning_rate: 1.0000e-05
# Epoch 42/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.6599 - loss: 0.0996 - mean_iou: 0.3723 - val_accuracy: 0.6866 - val_loss: 0.0945 - val_mean_iou: 0.3984 - learning_rate: 1.0000e-05
# Epoch 43/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.6627 - loss: 0.0986 - mean_iou: 0.3728 - val_accuracy: 0.6866 - val_loss: 0.0932 - val_mean_iou: 0.4001 - learning_rate: 1.0000e-05
# Epoch 44/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 32s 75ms/step - accuracy: 0.6629 - loss: 0.0982 - mean_iou: 0.3754 - val_accuracy: 0.6845 - val_loss: 0.0943 - val_mean_iou: 0.3990 - learning_rate: 1.0000e-05
# Epoch 45/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 74ms/step - accuracy: 0.6632 - loss: 0.0982 - mean_iou: 0.3737 - val_accuracy: 0.6797 - val_loss: 0.0944 - val_mean_iou: 0.3894 - learning_rate: 1.0000e-05
# Epoch 46/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.6617 - loss: 0.0989 - mean_iou: 0.3738 - val_accuracy: 0.6852 - val_loss: 0.0941 - val_mean_iou: 0.3965 - learning_rate: 1.0000e-05
# Epoch 47/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 33s 75ms/step - accuracy: 0.6644 - loss: 0.0977 - mean_iou: 0.3753 - val_accuracy: 0.6801 - val_loss: 0.0960 - val_mean_iou: 0.3950 - learning_rate: 1.0000e-05
# Epoch 48/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6671 - loss: 0.0969 - mean_iou: 0.3780
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 32s 74ms/step - accuracy: 0.6671 - loss: 0.0969 - mean_iou: 0.3779 - val_accuracy: 0.6828 - val_loss: 0.0948 - val_mean_iou: 0.3953 - learning_rate: 1.0000e-05
# Epoch 49/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 74ms/step - accuracy: 0.6708 - loss: 0.0960 - mean_iou: 0.3827 - val_accuracy: 0.6906 - val_loss: 0.0921 - val_mean_iou: 0.4030 - learning_rate: 2.0000e-06
# Epoch 50/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 75ms/step - accuracy: 0.6677 - loss: 0.0962 - mean_iou: 0.3804 - val_accuracy: 0.6904 - val_loss: 0.0917 - val_mean_iou: 0.4022 - learning_rate: 2.0000e-06
# Final validation Mean Intersection Over Union: 40.3%
# Model saved as residual_connections_function_40.3_20241205-173836.keras
# Training history saved as history_residual_connections_function_20241205-173836.json

# %%
plot_history(training, loss)

# %%
# Load model
model = tfk.models.load_model(model_filename, compile=False)
model.compile()
# Compile the model with specified loss, optimizer, and metrics
model.compile(
    loss=loss,
    optimizer=tfk.optimizers.AdamW(LEARNING_RATE),
    metrics=["accuracy", MeanIntersectionOverUnion(num_classes=NUM_CLASSES, labels_to_exclude=[0])]
)

# Evaluate the model on the test set and print the results
test_loss, test_accuracy, test_mean_iou = model.evaluate(test_dataset, verbose=0, batch_size=10)
print(f'Test Accuracy: {round(test_accuracy, 4)}')
print(f'Test Mean Intersection over Union: {round(test_mean_iou, 4)}')

# Plot three random samples
plot_triptychs(train_dataset, model, num_samples=30)
# Out:
# Test Accuracy: 0.6784
# Test Mean Intersection over Union: 0.3901

# %%
#compute predictions
preds = model.predict(X_final_test)
preds = np.argmax(preds, axis=-1)
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step

# %%
#to pandas dataframe
def y_to_df(y) -> pd.DataFrame:
    """Converts segmentation predictions into a DataFrame format for Kaggle."""
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
# Create and download the csv submission file
timestep_str = model_filename.replace("model_", "").replace(".keras", "")
submission_filename = f"submission_{timestep_str}.csv"
submission_df = y_to_df(preds)
submission_df.to_csv(submission_filename, index=False)

from google.colab import files
files.download(submission_filename)

# %% [markdown]
# ## Attention Decoder

# %%
def unet_trial2(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES, seed=seed):
    tf.random.set_seed(seed)
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    # Downsampling path
    down_block_1 = unet_block(input_layer, 32, name='down_block1_')
    d1 = tfkl.MaxPooling2D()(down_block_1)

    down_block_2 = unet_block(d1, 64, name='down_block2_')
    d2 = tfkl.MaxPooling2D()(down_block_2)

    # Bottleneck
    bottleneck = unet_block_bottleneck(d2, 128, name='bottleneck')

    # Upsampling path with attention gates
    u1 = tfkl.UpSampling2D()(bottleneck)
    u1 = attention_gate(down_block_2, u1, 64, 'attention1')
    u1 = unet_block(u1, 64, name='up_block1_')

    u2 = tfkl.UpSampling2D()(u1)
    u2 = attention_gate(down_block_1, u2, 32, 'attention2')
    u2 = unet_block(u2, 32, name='up_block2_')

    # Output Layer
    output_layer = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='output_layer')(u2)

    model = tf.keras.Model(inputs=input_layer, outputs=output_layer, name='UNet_Trial2')
    return model

# %%
training, model_filename = train_unet(
    model=unet_trial2(),
    loss_fn=loss,
    train_dataset=train_dataset,
    val_dataset=val_dataset,
    model_name='attention_decoder'
)
# Out:
# Epoch 1/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 72s 103ms/step - accuracy: 0.2391 - loss: 0.3038 - mean_iou: 0.1100 - val_accuracy: 0.2266 - val_loss: 0.2728 - val_mean_iou: 0.0716 - learning_rate: 1.0000e-05
# Epoch 2/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 58s 86ms/step - accuracy: 0.4011 - loss: 0.2284 - mean_iou: 0.1930 - val_accuracy: 0.5056 - val_loss: 0.2010 - val_mean_iou: 0.2652 - learning_rate: 1.0000e-05
# Epoch 3/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 88ms/step - accuracy: 0.5033 - loss: 0.1937 - mean_iou: 0.2593 - val_accuracy: 0.5767 - val_loss: 0.1721 - val_mean_iou: 0.3152 - learning_rate: 1.0000e-05
# Epoch 4/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.5522 - loss: 0.1738 - mean_iou: 0.2909 - val_accuracy: 0.6097 - val_loss: 0.1559 - val_mean_iou: 0.3423 - learning_rate: 1.0000e-05
# Epoch 5/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 86ms/step - accuracy: 0.5779 - loss: 0.1619 - mean_iou: 0.3075 - val_accuracy: 0.6243 - val_loss: 0.1463 - val_mean_iou: 0.3490 - learning_rate: 1.0000e-05
# Epoch 6/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.5941 - loss: 0.1518 - mean_iou: 0.3189 - val_accuracy: 0.6359 - val_loss: 0.1393 - val_mean_iou: 0.3565 - learning_rate: 1.0000e-05
# Epoch 7/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6079 - loss: 0.1449 - mean_iou: 0.3303 - val_accuracy: 0.6469 - val_loss: 0.1330 - val_mean_iou: 0.3665 - learning_rate: 1.0000e-05
# Epoch 8/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 88ms/step - accuracy: 0.6226 - loss: 0.1377 - mean_iou: 0.3385 - val_accuracy: 0.6567 - val_loss: 0.1283 - val_mean_iou: 0.3715 - learning_rate: 1.0000e-05
# Epoch 9/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 36s 86ms/step - accuracy: 0.6284 - loss: 0.1340 - mean_iou: 0.3462 - val_accuracy: 0.6552 - val_loss: 0.1301 - val_mean_iou: 0.3722 - learning_rate: 1.0000e-05
# Epoch 10/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 86ms/step - accuracy: 0.6318 - loss: 0.1303 - mean_iou: 0.3482 - val_accuracy: 0.6662 - val_loss: 0.1238 - val_mean_iou: 0.3795 - learning_rate: 1.0000e-05
# Epoch 11/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 87ms/step - accuracy: 0.6395 - loss: 0.1257 - mean_iou: 0.3539 - val_accuracy: 0.6457 - val_loss: 0.1260 - val_mean_iou: 0.3646 - learning_rate: 1.0000e-05
# Epoch 12/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6388 - loss: 0.1237 - mean_iou: 0.3534 - val_accuracy: 0.6812 - val_loss: 0.1138 - val_mean_iou: 0.3911 - learning_rate: 1.0000e-05
# Epoch 13/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6441 - loss: 0.1216 - mean_iou: 0.3565 - val_accuracy: 0.6791 - val_loss: 0.1120 - val_mean_iou: 0.3897 - learning_rate: 1.0000e-05
# Epoch 14/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6512 - loss: 0.1183 - mean_iou: 0.3638 - val_accuracy: 0.6857 - val_loss: 0.1099 - val_mean_iou: 0.3949 - learning_rate: 1.0000e-05
# Epoch 15/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6534 - loss: 0.1154 - mean_iou: 0.3685 - val_accuracy: 0.6845 - val_loss: 0.1074 - val_mean_iou: 0.3926 - learning_rate: 1.0000e-05
# Epoch 16/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 87ms/step - accuracy: 0.6516 - loss: 0.1151 - mean_iou: 0.3644 - val_accuracy: 0.6696 - val_loss: 0.1109 - val_mean_iou: 0.3825 - learning_rate: 1.0000e-05
# Epoch 17/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6597 - loss: 0.1118 - mean_iou: 0.3692 - val_accuracy: 0.6833 - val_loss: 0.1059 - val_mean_iou: 0.3899 - learning_rate: 1.0000e-05
# Epoch 18/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6579 - loss: 0.1112 - mean_iou: 0.3694 - val_accuracy: 0.6847 - val_loss: 0.1081 - val_mean_iou: 0.3986 - learning_rate: 1.0000e-05
# Epoch 19/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6639 - loss: 0.1083 - mean_iou: 0.3753 - val_accuracy: 0.6983 - val_loss: 0.1004 - val_mean_iou: 0.4052 - learning_rate: 1.0000e-05
# Epoch 20/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6675 - loss: 0.1058 - mean_iou: 0.3750 - val_accuracy: 0.6964 - val_loss: 0.1008 - val_mean_iou: 0.4011 - learning_rate: 1.0000e-05
# Epoch 21/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6679 - loss: 0.1057 - mean_iou: 0.3754 - val_accuracy: 0.6597 - val_loss: 0.1095 - val_mean_iou: 0.3697 - learning_rate: 1.0000e-05
# Epoch 22/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 86ms/step - accuracy: 0.6687 - loss: 0.1048 - mean_iou: 0.3763 - val_accuracy: 0.6867 - val_loss: 0.1013 - val_mean_iou: 0.3989 - learning_rate: 1.0000e-05
# Epoch 23/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6700 - loss: 0.1038 - mean_iou: 0.3782 - val_accuracy: 0.6999 - val_loss: 0.0974 - val_mean_iou: 0.4087 - learning_rate: 1.0000e-05
# Epoch 24/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 87ms/step - accuracy: 0.6747 - loss: 0.1015 - mean_iou: 0.3823 - val_accuracy: 0.7024 - val_loss: 0.0953 - val_mean_iou: 0.4088 - learning_rate: 1.0000e-05
# Epoch 25/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 87ms/step - accuracy: 0.6766 - loss: 0.1011 - mean_iou: 0.3833 - val_accuracy: 0.7072 - val_loss: 0.0944 - val_mean_iou: 0.4169 - learning_rate: 1.0000e-05
# Epoch 26/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6776 - loss: 0.0993 - mean_iou: 0.3855 - val_accuracy: 0.6925 - val_loss: 0.0999 - val_mean_iou: 0.4040 - learning_rate: 1.0000e-05
# Epoch 27/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6741 - loss: 0.0998 - mean_iou: 0.3841 - val_accuracy: 0.7037 - val_loss: 0.0942 - val_mean_iou: 0.4107 - learning_rate: 1.0000e-05
# Epoch 28/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6774 - loss: 0.0989 - mean_iou: 0.3854 - val_accuracy: 0.7021 - val_loss: 0.0948 - val_mean_iou: 0.4079 - learning_rate: 1.0000e-05
# Epoch 29/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6816 - loss: 0.0972 - mean_iou: 0.3887 - val_accuracy: 0.7143 - val_loss: 0.0896 - val_mean_iou: 0.4244 - learning_rate: 1.0000e-05
# Epoch 30/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6844 - loss: 0.0961 - mean_iou: 0.3928 - val_accuracy: 0.7005 - val_loss: 0.0922 - val_mean_iou: 0.4045 - learning_rate: 1.0000e-05
# Epoch 31/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6852 - loss: 0.0956 - mean_iou: 0.3905 - val_accuracy: 0.6949 - val_loss: 0.0951 - val_mean_iou: 0.4041 - learning_rate: 1.0000e-05
# Epoch 32/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6836 - loss: 0.0954 - mean_iou: 0.3911 - val_accuracy: 0.6988 - val_loss: 0.0975 - val_mean_iou: 0.4069 - learning_rate: 1.0000e-05
# Epoch 33/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6871 - loss: 0.0945 - mean_iou: 0.3922 - val_accuracy: 0.7076 - val_loss: 0.0929 - val_mean_iou: 0.4144 - learning_rate: 1.0000e-05
# Epoch 34/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6860 - loss: 0.0944 - mean_iou: 0.3918
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 88ms/step - accuracy: 0.6860 - loss: 0.0944 - mean_iou: 0.3918 - val_accuracy: 0.7013 - val_loss: 0.0918 - val_mean_iou: 0.4081 - learning_rate: 1.0000e-05
# Epoch 35/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6916 - loss: 0.0923 - mean_iou: 0.4003 - val_accuracy: 0.7184 - val_loss: 0.0872 - val_mean_iou: 0.4262 - learning_rate: 2.0000e-06
# Epoch 36/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6904 - loss: 0.0926 - mean_iou: 0.3975 - val_accuracy: 0.7172 - val_loss: 0.0871 - val_mean_iou: 0.4222 - learning_rate: 2.0000e-06
# Epoch 37/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 36s 87ms/step - accuracy: 0.6914 - loss: 0.0920 - mean_iou: 0.3984 - val_accuracy: 0.7163 - val_loss: 0.0872 - val_mean_iou: 0.4223 - learning_rate: 2.0000e-06
# Epoch 38/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 88ms/step - accuracy: 0.6938 - loss: 0.0921 - mean_iou: 0.3982 - val_accuracy: 0.7194 - val_loss: 0.0866 - val_mean_iou: 0.4264 - learning_rate: 2.0000e-06
# Epoch 39/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 87ms/step - accuracy: 0.6967 - loss: 0.0906 - mean_iou: 0.4032 - val_accuracy: 0.7201 - val_loss: 0.0863 - val_mean_iou: 0.4294 - learning_rate: 2.0000e-06
# Epoch 40/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6902 - loss: 0.0922 - mean_iou: 0.3975 - val_accuracy: 0.7190 - val_loss: 0.0861 - val_mean_iou: 0.4278 - learning_rate: 2.0000e-06
# Epoch 41/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6945 - loss: 0.0921 - mean_iou: 0.3992 - val_accuracy: 0.7173 - val_loss: 0.0868 - val_mean_iou: 0.4259 - learning_rate: 2.0000e-06
# Epoch 42/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6943 - loss: 0.0914 - mean_iou: 0.4000 - val_accuracy: 0.7214 - val_loss: 0.0857 - val_mean_iou: 0.4283 - learning_rate: 2.0000e-06
# Epoch 43/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6960 - loss: 0.0906 - mean_iou: 0.4003 - val_accuracy: 0.7211 - val_loss: 0.0861 - val_mean_iou: 0.4292 - learning_rate: 2.0000e-06
# Epoch 44/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 87ms/step - accuracy: 0.6961 - loss: 0.0902 - mean_iou: 0.4021 - val_accuracy: 0.7169 - val_loss: 0.0868 - val_mean_iou: 0.4229 - learning_rate: 2.0000e-06
# Epoch 45/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 87ms/step - accuracy: 0.6957 - loss: 0.0907 - mean_iou: 0.4003 - val_accuracy: 0.7160 - val_loss: 0.0871 - val_mean_iou: 0.4237 - learning_rate: 2.0000e-06
# Epoch 46/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6935 - loss: 0.0915 - mean_iou: 0.4005 - val_accuracy: 0.7158 - val_loss: 0.0874 - val_mean_iou: 0.4208 - learning_rate: 2.0000e-06
# Epoch 47/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6952 - loss: 0.0903 - mean_iou: 0.4013
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-06.
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6952 - loss: 0.0903 - mean_iou: 0.4013 - val_accuracy: 0.7224 - val_loss: 0.0857 - val_mean_iou: 0.4294 - learning_rate: 2.0000e-06
# Epoch 48/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6979 - loss: 0.0893 - mean_iou: 0.4033 - val_accuracy: 0.7209 - val_loss: 0.0858 - val_mean_iou: 0.4279 - learning_rate: 1.0000e-06
# Epoch 49/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 87ms/step - accuracy: 0.6984 - loss: 0.0897 - mean_iou: 0.4040 - val_accuracy: 0.7193 - val_loss: 0.0867 - val_mean_iou: 0.4272 - learning_rate: 1.0000e-06
# Epoch 50/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6951 - loss: 0.0901 - mean_iou: 0.4024 - val_accuracy: 0.7210 - val_loss: 0.0854 - val_mean_iou: 0.4282 - learning_rate: 1.0000e-06
# Final validation Mean Intersection Over Union: 42.94%
# Model saved as attention_decoder_function_42.94_20241205-173302.keras
# Training history saved as history_attention_decoder_function_20241205-173302.json

# %%
plot_history(training, loss)

# %%
# Load model
model = tfk.models.load_model(model_filename, compile=False)

# Compile the model with specified loss, optimizer, and metrics
model.compile(
    loss=loss,
    optimizer=tfk.optimizers.AdamW(LEARNING_RATE),
    metrics=["accuracy", MeanIntersectionOverUnion(num_classes=NUM_CLASSES, labels_to_exclude=[0])]
)

# Evaluate the model on the test set and print the results
test_loss, test_accuracy, test_mean_iou = model.evaluate(test_dataset, verbose=0, batch_size=10)
print(f'Test Accuracy: {round(test_accuracy, 4)}')
print(f'Test Mean Intersection over Union: {round(test_mean_iou, 4)}')

# Plot three random samples
plot_triptychs(train_dataset, model, num_samples=30)
# Out:
# Test Accuracy: 0.7026
# Test Mean Intersection over Union: 0.4101

# %%
#compute predictions
preds = model.predict(X_final_test)
preds = np.argmax(preds, axis=-1)
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step

# %%
#to pandas dataframe
def y_to_df(y) -> pd.DataFrame:
    """Converts segmentation predictions into a DataFrame format for Kaggle."""
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
# Create and download the csv submission file
timestep_str = model_filename.replace("model_", "").replace(".keras", "")
submission_filename = f"submission_{timestep_str}.csv"
submission_df = y_to_df(preds)
submission_df.to_csv(submission_filename, index=False)

from google.colab import files
files.download(submission_filename)

# %% [markdown]
# ## Gated Skip Connection

# %%
def unet_trial1(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES, seed=seed):
    tf.random.set_seed(seed)
    input_layer = tfkl.Input(shape=input_shape, name='input_layer')

    # Downsampling path
    down_block_1 = unet_block(input_layer, 32, name='down_block1_')
    d1 = tfkl.MaxPooling2D()(down_block_1)

    down_block_2 = unet_block(d1, 64, name='down_block2_')
    d2 = tfkl.MaxPooling2D()(down_block_2)

    # Bottleneck
    bottleneck = unet_block_bottleneck(d2, 128, name='bottleneck')

    # Upsampling path with gated skip connections
    u1 = tfkl.UpSampling2D()(bottleneck)
    u1 = gated_skip_connection(down_block_2, u1, 64, 'gate1')
    u1 = unet_block(u1, 64, name='up_block1_')

    u2 = tfkl.UpSampling2D()(u1)
    u2 = gated_skip_connection(down_block_1, u2, 32, 'gate2')
    u2 = unet_block(u2, 32, name='up_block2_')

    # Output Layer
    output_layer = tfkl.Conv2D(num_classes, kernel_size=1, padding='same', activation="softmax", name='output_layer')(u2)

    model = tf.keras.Model(inputs=input_layer, outputs=output_layer, name='UNet_Trial1')
    return model

# %%
training, model_filename = train_unet(
    model=unet_trial1(),
    loss_fn=loss,
    train_dataset=train_dataset,
    val_dataset=val_dataset,
    model_name='gated_skip'
)
# Out:
# Epoch 1/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 76s 104ms/step - accuracy: 0.2391 - loss: 0.3038 - mean_iou: 0.1100 - val_accuracy: 0.2266 - val_loss: 0.2728 - val_mean_iou: 0.0716 - learning_rate: 1.0000e-05
# Epoch 2/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 53s 83ms/step - accuracy: 0.4011 - loss: 0.2284 - mean_iou: 0.1930 - val_accuracy: 0.5054 - val_loss: 0.2011 - val_mean_iou: 0.2651 - learning_rate: 1.0000e-05
# Epoch 3/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 36s 84ms/step - accuracy: 0.5033 - loss: 0.1937 - mean_iou: 0.2593 - val_accuracy: 0.5765 - val_loss: 0.1721 - val_mean_iou: 0.3150 - learning_rate: 1.0000e-05
# Epoch 4/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 87ms/step - accuracy: 0.5522 - loss: 0.1738 - mean_iou: 0.2909 - val_accuracy: 0.6098 - val_loss: 0.1559 - val_mean_iou: 0.3422 - learning_rate: 1.0000e-05
# Epoch 5/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 89ms/step - accuracy: 0.5779 - loss: 0.1619 - mean_iou: 0.3075 - val_accuracy: 0.6250 - val_loss: 0.1461 - val_mean_iou: 0.3499 - learning_rate: 1.0000e-05
# Epoch 6/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.5941 - loss: 0.1518 - mean_iou: 0.3189 - val_accuracy: 0.6358 - val_loss: 0.1393 - val_mean_iou: 0.3566 - learning_rate: 1.0000e-05
# Epoch 7/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.6079 - loss: 0.1449 - mean_iou: 0.3303 - val_accuracy: 0.6463 - val_loss: 0.1332 - val_mean_iou: 0.3659 - learning_rate: 1.0000e-05
# Epoch 8/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 89ms/step - accuracy: 0.6225 - loss: 0.1377 - mean_iou: 0.3384 - val_accuracy: 0.6570 - val_loss: 0.1280 - val_mean_iou: 0.3719 - learning_rate: 1.0000e-05
# Epoch 9/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6284 - loss: 0.1340 - mean_iou: 0.3462 - val_accuracy: 0.6557 - val_loss: 0.1299 - val_mean_iou: 0.3726 - learning_rate: 1.0000e-05
# Epoch 10/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6318 - loss: 0.1303 - mean_iou: 0.3482 - val_accuracy: 0.6661 - val_loss: 0.1239 - val_mean_iou: 0.3795 - learning_rate: 1.0000e-05
# Epoch 11/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6395 - loss: 0.1257 - mean_iou: 0.3538 - val_accuracy: 0.6457 - val_loss: 0.1259 - val_mean_iou: 0.3648 - learning_rate: 1.0000e-05
# Epoch 12/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6388 - loss: 0.1237 - mean_iou: 0.3533 - val_accuracy: 0.6813 - val_loss: 0.1137 - val_mean_iou: 0.3913 - learning_rate: 1.0000e-05
# Epoch 13/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6441 - loss: 0.1216 - mean_iou: 0.3565 - val_accuracy: 0.6801 - val_loss: 0.1116 - val_mean_iou: 0.3908 - learning_rate: 1.0000e-05
# Epoch 14/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 88ms/step - accuracy: 0.6512 - loss: 0.1183 - mean_iou: 0.3638 - val_accuracy: 0.6860 - val_loss: 0.1098 - val_mean_iou: 0.3952 - learning_rate: 1.0000e-05
# Epoch 15/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.6534 - loss: 0.1154 - mean_iou: 0.3685 - val_accuracy: 0.6849 - val_loss: 0.1073 - val_mean_iou: 0.3930 - learning_rate: 1.0000e-05
# Epoch 16/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 88ms/step - accuracy: 0.6516 - loss: 0.1151 - mean_iou: 0.3645 - val_accuracy: 0.6693 - val_loss: 0.1109 - val_mean_iou: 0.3824 - learning_rate: 1.0000e-05
# Epoch 17/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6597 - loss: 0.1118 - mean_iou: 0.3693 - val_accuracy: 0.6838 - val_loss: 0.1058 - val_mean_iou: 0.3904 - learning_rate: 1.0000e-05
# Epoch 18/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6579 - loss: 0.1112 - mean_iou: 0.3694 - val_accuracy: 0.6863 - val_loss: 0.1074 - val_mean_iou: 0.4003 - learning_rate: 1.0000e-05
# Epoch 19/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6640 - loss: 0.1083 - mean_iou: 0.3754 - val_accuracy: 0.6975 - val_loss: 0.1005 - val_mean_iou: 0.4044 - learning_rate: 1.0000e-05
# Epoch 20/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6675 - loss: 0.1058 - mean_iou: 0.3750 - val_accuracy: 0.6989 - val_loss: 0.0998 - val_mean_iou: 0.4036 - learning_rate: 1.0000e-05
# Epoch 21/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6679 - loss: 0.1057 - mean_iou: 0.3755 - val_accuracy: 0.6626 - val_loss: 0.1086 - val_mean_iou: 0.3724 - learning_rate: 1.0000e-05
# Epoch 22/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6687 - loss: 0.1048 - mean_iou: 0.3763 - val_accuracy: 0.6819 - val_loss: 0.1029 - val_mean_iou: 0.3942 - learning_rate: 1.0000e-05
# Epoch 23/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6700 - loss: 0.1038 - mean_iou: 0.3782 - val_accuracy: 0.7007 - val_loss: 0.0972 - val_mean_iou: 0.4097 - learning_rate: 1.0000e-05
# Epoch 24/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6747 - loss: 0.1015 - mean_iou: 0.3824 - val_accuracy: 0.7027 - val_loss: 0.0952 - val_mean_iou: 0.4092 - learning_rate: 1.0000e-05
# Epoch 25/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6766 - loss: 0.1011 - mean_iou: 0.3833 - val_accuracy: 0.7073 - val_loss: 0.0943 - val_mean_iou: 0.4172 - learning_rate: 1.0000e-05
# Epoch 26/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6776 - loss: 0.0993 - mean_iou: 0.3855 - val_accuracy: 0.6915 - val_loss: 0.1002 - val_mean_iou: 0.4028 - learning_rate: 1.0000e-05
# Epoch 27/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6742 - loss: 0.0998 - mean_iou: 0.3841 - val_accuracy: 0.7042 - val_loss: 0.0941 - val_mean_iou: 0.4114 - learning_rate: 1.0000e-05
# Epoch 28/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6773 - loss: 0.0989 - mean_iou: 0.3854 - val_accuracy: 0.7018 - val_loss: 0.0951 - val_mean_iou: 0.4076 - learning_rate: 1.0000e-05
# Epoch 29/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6816 - loss: 0.0972 - mean_iou: 0.3887 - val_accuracy: 0.7135 - val_loss: 0.0898 - val_mean_iou: 0.4236 - learning_rate: 1.0000e-05
# Epoch 30/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6844 - loss: 0.0961 - mean_iou: 0.3928 - val_accuracy: 0.6990 - val_loss: 0.0927 - val_mean_iou: 0.4027 - learning_rate: 1.0000e-05
# Epoch 31/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 88ms/step - accuracy: 0.6852 - loss: 0.0956 - mean_iou: 0.3905 - val_accuracy: 0.6936 - val_loss: 0.0956 - val_mean_iou: 0.4026 - learning_rate: 1.0000e-05
# Epoch 32/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 89ms/step - accuracy: 0.6837 - loss: 0.0954 - mean_iou: 0.3911 - val_accuracy: 0.6985 - val_loss: 0.0976 - val_mean_iou: 0.4064 - learning_rate: 1.0000e-05
# Epoch 33/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6871 - loss: 0.0945 - mean_iou: 0.3923 - val_accuracy: 0.7087 - val_loss: 0.0924 - val_mean_iou: 0.4152 - learning_rate: 1.0000e-05
# Epoch 34/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6860 - loss: 0.0944 - mean_iou: 0.3918
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.6860 - loss: 0.0944 - mean_iou: 0.3918 - val_accuracy: 0.7009 - val_loss: 0.0918 - val_mean_iou: 0.4080 - learning_rate: 1.0000e-05
# Epoch 35/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6916 - loss: 0.0923 - mean_iou: 0.4003 - val_accuracy: 0.7186 - val_loss: 0.0872 - val_mean_iou: 0.4264 - learning_rate: 2.0000e-06
# Epoch 36/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6904 - loss: 0.0926 - mean_iou: 0.3975 - val_accuracy: 0.7172 - val_loss: 0.0871 - val_mean_iou: 0.4222 - learning_rate: 2.0000e-06
# Epoch 37/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 88ms/step - accuracy: 0.6913 - loss: 0.0920 - mean_iou: 0.3984 - val_accuracy: 0.7164 - val_loss: 0.0872 - val_mean_iou: 0.4224 - learning_rate: 2.0000e-06
# Epoch 38/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.6939 - loss: 0.0921 - mean_iou: 0.3982 - val_accuracy: 0.7195 - val_loss: 0.0866 - val_mean_iou: 0.4266 - learning_rate: 2.0000e-06
# Epoch 39/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.6967 - loss: 0.0906 - mean_iou: 0.4032 - val_accuracy: 0.7201 - val_loss: 0.0863 - val_mean_iou: 0.4295 - learning_rate: 2.0000e-06
# Epoch 40/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.6902 - loss: 0.0922 - mean_iou: 0.3975 - val_accuracy: 0.7192 - val_loss: 0.0861 - val_mean_iou: 0.4280 - learning_rate: 2.0000e-06
# Epoch 41/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6945 - loss: 0.0921 - mean_iou: 0.3992 - val_accuracy: 0.7169 - val_loss: 0.0869 - val_mean_iou: 0.4254 - learning_rate: 2.0000e-06
# Epoch 42/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 88ms/step - accuracy: 0.6943 - loss: 0.0914 - mean_iou: 0.4000 - val_accuracy: 0.7214 - val_loss: 0.0856 - val_mean_iou: 0.4283 - learning_rate: 2.0000e-06
# Epoch 43/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6960 - loss: 0.0906 - mean_iou: 0.4003 - val_accuracy: 0.7211 - val_loss: 0.0861 - val_mean_iou: 0.4292 - learning_rate: 2.0000e-06
# Epoch 44/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.6961 - loss: 0.0902 - mean_iou: 0.4021 - val_accuracy: 0.7168 - val_loss: 0.0868 - val_mean_iou: 0.4229 - learning_rate: 2.0000e-06
# Epoch 45/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.6957 - loss: 0.0907 - mean_iou: 0.4003 - val_accuracy: 0.7163 - val_loss: 0.0870 - val_mean_iou: 0.4239 - learning_rate: 2.0000e-06
# Epoch 46/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 37s 88ms/step - accuracy: 0.6935 - loss: 0.0915 - mean_iou: 0.4005 - val_accuracy: 0.7159 - val_loss: 0.0873 - val_mean_iou: 0.4209 - learning_rate: 2.0000e-06
# Epoch 47/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6953 - loss: 0.0903 - mean_iou: 0.4013
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-06.
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 38s 87ms/step - accuracy: 0.6953 - loss: 0.0903 - mean_iou: 0.4013 - val_accuracy: 0.7224 - val_loss: 0.0857 - val_mean_iou: 0.4294 - learning_rate: 2.0000e-06
# Epoch 48/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 41s 89ms/step - accuracy: 0.6980 - loss: 0.0893 - mean_iou: 0.4033 - val_accuracy: 0.7209 - val_loss: 0.0858 - val_mean_iou: 0.4279 - learning_rate: 1.0000e-06
# Epoch 49/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 40s 87ms/step - accuracy: 0.6984 - loss: 0.0898 - mean_iou: 0.4040 - val_accuracy: 0.7192 - val_loss: 0.0867 - val_mean_iou: 0.4271 - learning_rate: 1.0000e-06
# Epoch 50/50
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 42s 88ms/step - accuracy: 0.6951 - loss: 0.0901 - mean_iou: 0.4024 - val_accuracy: 0.7210 - val_loss: 0.0854 - val_mean_iou: 0.4282 - learning_rate: 1.0000e-06
# Final validation Mean Intersection Over Union: 42.95%
# Model saved as gated_skip_function_42.95_20241205-173123.keras
# Training history saved as history_gated_skip_function_20241205-173123.json

# %%
plot_history(training, loss)

# %%
# Load model
model = tfk.models.load_model(model_filename, compile=False)

# Compile the model with specified loss, optimizer, and metrics
model.compile(
    loss=loss,
    optimizer=tfk.optimizers.AdamW(LEARNING_RATE),
    metrics=["accuracy", MeanIntersectionOverUnion(num_classes=NUM_CLASSES, labels_to_exclude=[0])]
)

# Evaluate the model on the test set and print the results
test_loss, test_accuracy, test_mean_iou = model.evaluate(test_dataset, verbose=0, batch_size=10)
print(f'Test Accuracy: {round(test_accuracy, 4)}')
print(f'Test Mean Intersection over Union: {round(test_mean_iou, 4)}')

# Plot three random samples
plot_triptychs(train_dataset, model, num_samples=30)
# Out:
# Test Accuracy: 0.7027
# Test Mean Intersection over Union: 0.4102

# %%
#compute predictions
preds = model.predict(X_final_test)
preds = np.argmax(preds, axis=-1)
# Out:
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step

# %%
#to pandas dataframe
def y_to_df(y) -> pd.DataFrame:
    """Converts segmentation predictions into a DataFrame format for Kaggle."""
    n_samples = len(y)
    y_flat = y.reshape(n_samples, -1)
    df = pd.DataFrame(y_flat)
    df["id"] = np.arange(n_samples)
    cols = ["id"] + [col for col in df.columns if col != "id"]
    return df[cols]

# %%
# Create and download the csv submission file
timestep_str = model_filename.replace("model_", "").replace(".keras", "")
submission_filename = f"submission_{timestep_str}.csv"
submission_df = y_to_df(preds)
submission_df.to_csv(submission_filename, index=False)

from google.colab import files
files.download(submission_filename)
